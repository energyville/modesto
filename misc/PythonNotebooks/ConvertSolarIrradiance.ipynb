# %%
import pandas as pd

# %%
data = pd.read_csv('../../modesto/Data/RenewableProduction/DirectDiffuseRadiation_00_40.csv', sep=';', decimal=',')

# %%
data = data.drop('Seconds', axis=1)

# %%
data['DateTime'] = pd.DatetimeIndex(start='20140101', freq='60S', periods=len(data))

# %%
data = data.set_index('DateTime')

# %%
data
# Out:
#                       Diffuse  Direct
# DateTime
# 2014-01-01 00:00:00  0.000083     0.0
# 2014-01-01 00:01:00  0.000083     0.0
# 2014-01-01 00:02:00  0.000083     0.0
# 2014-01-01 00:03:00  0.000083     0.0
# 2014-01-01 00:04:00  0.000083     0.0
# 2014-01-01 00:05:00  0.000083     0.0
# 2014-01-01 00:06:00  0.000083     0.0
# 2014-01-01 00:07:00  0.000083     0.0
# 2014-01-01 00:08:00  0.000083     0.0
# 2014-01-01 00:09:00  0.000083     0.0
# 2014-01-01 00:10:00  0.000083     0.0
# 2014-01-01 00:11:00  0.000083     0.0
# 2014-01-01 00:12:00  0.000083     0.0
# 2014-01-01 00:13:00  0.000083     0.0
# 2014-01-01 00:14:00  0.000083     0.0
# 2014-01-01 00:15:00  0.000083     0.0
# 2014-01-01 00:16:00  0.000083     0.0
# 2014-01-01 00:17:00  0.000083     0.0
# 2014-01-01 00:18:00  0.000083     0.0
# 2014-01-01 00:19:00  0.000083     0.0
# 2014-01-01 00:20:00  0.000083     0.0
# 2014-01-01 00:21:00  0.000083     0.0
# 2014-01-01 00:22:00  0.000083     0.0
# ...

# %%
# %matplotlib notebook
data.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_export = pd.DataFrame()
data_export['0_40'] = data['Diffuse'] + data['Direct']

# %%
data_export[data_export['0_40'] < 0.0001] = 0

# %%
data_export.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_export.to_csv('../../modesto/Data/RenewableProduction/GlobalRadiation.csv', sep=';')

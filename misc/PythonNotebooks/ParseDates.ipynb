# %%
import pandas as pd

# %%
Test = pd.read_csv('../../modesto/Data/ElectricityPrices/DAM_prices_and_volumes_hourly.csv', sep=';', 
                   parse_dates=True, dayfirst=True, index_col=0)

# %%
Test
# Out:
#                      price_DE  volume_DE  price_FR  volume_FR  price_CH  \
# datetime_be
# 2005-02-08 00:00:00   0.03188     8218.2       NaN        NaN       NaN
# 2005-02-08 01:00:00   0.02937     8160.7       NaN        NaN       NaN
# 2005-02-08 02:00:00   0.03142     7702.9       NaN        NaN       NaN
# 2005-02-08 03:00:00   0.02978     8164.0       NaN        NaN       NaN
# 2005-02-08 04:00:00   0.03012     7635.6       NaN        NaN       NaN
# 2005-02-08 05:00:00   0.03209     7464.6       NaN        NaN       NaN
# 2005-02-08 06:00:00   0.03357     8666.6       NaN        NaN       NaN
# 2005-02-08 07:00:00   0.04407     9775.5       NaN        NaN       NaN
# 2005-02-08 08:00:00   0.04892     9979.7       NaN        NaN       NaN
# 2005-02-08 09:00:00   0.05039    10040.7       NaN        NaN       NaN
# 2005-02-08 10:00:00   0.05109     9749.1       NaN        NaN       NaN
# 2005-02-08 11:00:00   0.05299    10021.4       NaN        NaN       NaN
# ...

# %%
Test.to_csv('../../modesto/Data/ElectricityPrices/DAM_prices_and_volumes_hourly_new.csv', sep=';')

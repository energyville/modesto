# %%
import pandas as pd
from pkg_resources import resource_filename
import os
import matplotlib.pyplot as plt
# %matplotlib inline

DATA = resource_filename('modesto', 'Data/Investment/Pipe.xlsx')
print(DATA)
# Out:
# c:\users\u0094934\research\modesto\modesto\Data\Investment\Pipe.xlsx

# %%
df = pd.read_excel(DATA, index_col='DN')

# %%
df.plot()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

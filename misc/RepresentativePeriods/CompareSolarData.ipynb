# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
data_optides = pd.read_csv('C:/Users/u0094934/Research/OptiDES/Preprocess/Result.txt', sep=' ', index_col=0, parse_dates=True)

# %%
data_optides
# Out:
#                      0_0  0_40  -30_40  30_40
# Date
# 2014-01-01 00:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 00:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 00:30:00  0.0   0.0     0.0    0.0
# 2014-01-01 00:45:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:30:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:45:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:30:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:45:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:30:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:45:00  0.0   0.0     0.0    0.0
# 2014-01-01 04:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 04:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 04:30:00  0.0   0.0     0.0    0.0
# ...

# %%
data_districtopt = pd.read_csv('C:/Users/u0094934/Research/DistrictOpt/DistrictOpt/Data/Renewable/SolarThermal.txt', 
                               sep=' ', parse_dates=True, index_col=0)

# %%
data_districtopt
# Out:
#                      (0L, 0L)  (-90L, 40L)  (-60L, 40L)  (-30L, 40L)  \
# Date
# 2014-01-01 00:00:00       0.0          0.0          0.0          0.0
# 2014-01-01 00:15:00       0.0          0.0          0.0          0.0
# 2014-01-01 00:30:00       0.0          0.0          0.0          0.0
# 2014-01-01 00:45:00       0.0          0.0          0.0          0.0
# 2014-01-01 01:00:00       0.0          0.0          0.0          0.0
# 2014-01-01 01:15:00       0.0          0.0          0.0          0.0
# 2014-01-01 01:30:00       0.0          0.0          0.0          0.0
# 2014-01-01 01:45:00       0.0          0.0          0.0          0.0
# 2014-01-01 02:00:00       0.0          0.0          0.0          0.0
# 2014-01-01 02:15:00       0.0          0.0          0.0          0.0
# 2014-01-01 02:30:00       0.0          0.0          0.0          0.0
# 2014-01-01 02:45:00       0.0          0.0          0.0          0.0
# ...

# %%
data_modesto =  pd.read_csv('C:/Users/u0094934/Research/modesto/modesto/Data/RenewableProduction/SolarThermalNew.csv', 
                               sep=';', parse_dates=True, index_col=0)

# %%
data_modesto
# Out:
#                      0_0  0_40  -30_40  30_40
# Date
# 2014-01-01 00:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 00:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 00:30:00  0.0   0.0     0.0    0.0
# 2014-01-01 00:45:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:30:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:45:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:30:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:45:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:30:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:45:00  0.0   0.0     0.0    0.0
# 2014-01-01 04:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 04:15:00  0.0   0.0     0.0    0.0
# 2014-01-01 04:30:00  0.0   0.0     0.0    0.0
# ...

# %%
fig, ax = plt.subplots()
ax.plot(data_optides['0_40'], label='OptiDES')
ax.plot(data_districtopt['(0L, 40L)'], '--', label='DistrictOpt')
ax.plot(data_optides['0_40'], ':', label='modesto')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.plot(data_optides['0_40'], label='OptiDES')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.plot(data_districtopt['(0L, 40L)'], label='DistrictOpt')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_modesto_old = pd.read_csv('C:/Users/u0094934/Research/modesto/modesto/Data/RenewableProduction/SolarThermal.csv', sep=';',
                              parse_dates=True, index_col=0)

# %%
data_modesto_old
# Out:
#                      (0L, 0L)  (-90L, 40L)  (-60L, 40L)  (-30L, 40L)  \
# Date
# 2014-01-01 00:00:00       0.0          0.0          0.0          0.0
# 2014-01-01 00:15:00       0.0          0.0          0.0          0.0
# 2014-01-01 00:30:00       0.0          0.0          0.0          0.0
# 2014-01-01 00:45:00       0.0          0.0          0.0          0.0
# 2014-01-01 01:00:00       0.0          0.0          0.0          0.0
# 2014-01-01 01:15:00       0.0          0.0          0.0          0.0
# 2014-01-01 01:30:00       0.0          0.0          0.0          0.0
# 2014-01-01 01:45:00       0.0          0.0          0.0          0.0
# 2014-01-01 02:00:00       0.0          0.0          0.0          0.0
# 2014-01-01 02:15:00       0.0          0.0          0.0          0.0
# 2014-01-01 02:30:00       0.0          0.0          0.0          0.0
# 2014-01-01 02:45:00       0.0          0.0          0.0          0.0
# ...

# %%
fig, ax = plt.subplots()
ax.plot(data_modesto_old['(0L, 40L)']- data_districtopt['(0L, 40L)'], label='OptiDES')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline
plt.plot(sorted(data_modesto_old['(0L, 40L)'].values, reverse=True))
plt.plot(sorted(data_districtopt['(0L, 40L)'].values, reverse=True))

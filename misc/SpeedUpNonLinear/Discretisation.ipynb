# %% [markdown]
# # Influence of discretisation

# %% [markdown]
# This code investigates the influence of the discretisation (both time and space) on the model outcome

# %%
import modesto.main
import modesto.utils as ut
from modesto.Tests.test_simple_network import branched_network_substation as opt_problem
from pkg_resources import resource_filename
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## Discretisation settings

# %%
horizon = 5*3600
time_step = 45
v_max = [3, 3, 3]

# %% [markdown]
# ## Setting up the DHN model

# %%
results = opt_problem(horizon, time_step, v_max)
# Out:
# 3
# pipe1 has 2 volumes, one element has a length of 100.0
# 3
# pipe2 has 3 volumes, one element has a length of 100.0
# 3
# pipe3 has 1 volumes, one element has a length of 100.0
# Time to compile:  4.60577654838562
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:    33161
# Number of nonzeros in inequality constraint Jacobian.:     1600
# Number of nonzeros in Lagrangian Hessian.............:    13182
#
# ...

# %% [markdown]
# ## Extract results

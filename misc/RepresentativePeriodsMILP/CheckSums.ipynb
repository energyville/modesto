# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('results_ordered/1dnewsol/result_ordered12p.txt', sep=' ', index_col=0)

# %%
data
# Out:
#            A      VSTC      VWat  E_backup_full  E_backup_repr  \
# 0    25000.0   50000.0   50000.0   1.834372e+08   1.830487e+08
# 1    25000.0  100000.0   50000.0   1.834759e+08   1.830934e+08
# 2    25000.0  150000.0   50000.0   1.835094e+08   1.831196e+08
# 3    50000.0   50000.0   50000.0   1.807183e+08   1.802496e+08
# 4    50000.0  100000.0   50000.0   1.807560e+08   1.802942e+08
# 5    50000.0  150000.0   50000.0   1.807895e+08   1.803219e+08
# 6    75000.0   50000.0   50000.0   1.780013e+08   1.774473e+08
# 7    75000.0  100000.0   50000.0   1.780372e+08   1.774900e+08
# 8    75000.0  150000.0   50000.0   1.780700e+08   1.775223e+08
# 9   100000.0   50000.0   50000.0   1.752841e+08   1.746499e+08
# 10  100000.0  100000.0   50000.0   1.753193e+08   1.746891e+08
# 11  100000.0  150000.0   50000.0   1.753506e+08   1.747178e+08
# 12   25000.0   50000.0   75000.0   1.834550e+08   1.830721e+08
# 13   25000.0  100000.0   75000.0   1.834944e+08   1.831118e+08
# ...

# %%
data['Full_dem'] = data[['E_demand_full', 'E_loss_stor_full', 'E_net_loss_full']].sum(axis=1)

# %%
data['Full_prod'] = data[['E_sol_full', 'E_backup_full']].sum(axis=1)

# %%
data['Repr_dem'] = data[['E_demand_repr', 'E_loss_stor_repr', 'E_net_loss_repr']].sum(axis=1)
data['Repr_prod'] = data[['E_sol_repr', 'E_backup_repr']].sum(axis=1)

# %%
# %matplotlib notebook

offset = 2500

plt.plot(data['A'], data['Full_dem'], 'o', label='Full dem side')
plt.plot(data['A']+offset, data['Full_prod'], 'o', label='Full prod side')
plt.plot(data['A'], data['Repr_dem'], 's', label='Repr dem side')
plt.plot(data['A']+offset, data['Repr_prod'], 's', label='Repr prod side')
plt.hlines([data['Full_dem'].mean()*0.975, data['Full_dem'].mean()*1.025], xmin=20000, xmax=110000, linestyles=':')
plt.plot(data['A'], data['E_demand_full'], '^', label='Full demand')
plt.plot(data['A'], data['E_demand_repr'], '^', label='Repr demand')
#plt.plot(data['A']+offset, data['E_curt_repr'], )
plt.legend()
# plt.ylim(0,None)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook 

name = 'backup'
fig, ax = plt.subplots()
for i, row in data.iterrows():
    ax.add_line(plt.Line2D(xdata=[row['A'], row['A']+2500], ydata=[row['E_{}_full'.format(name)], 
              row['E_{}_repr'.format(name)]], linestyle='-', linewidth=0.5))
    
ax.plot(data['A'], data['E_{}_full'.format(name)], 'o', label='Full {}'.format(name))
ax.plot(data['A']+2500, data['E_{}_repr'.format(name)], 's', label='Repr {}'.format(name))
ax.legend()
ax.set_ylim(0, None)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 183002138.5029316)

# %%
# %matplotlib notebook 

name = 'loss_stor'
fig, ax = plt.subplots()
for i, row in data.iterrows():
    ax.add_line(plt.Line2D(xdata=[row['A'], row['A']+2500], ydata=[row['E_{}_full'.format(name)], 
              row['E_{}_repr'.format(name)]], linestyle='-', linewidth=0.5))
ax.hlines(0.975*data['E_{}_full'.format(name)].iloc[0], xmin=0, xmax=110000, linestyles=':')
ax.hlines(1.075*data['E_{}_full'.format(name)].iloc[0], xmin=0, xmax=110000, linestyles=':')


ax.plot(data['A'], data['E_{}_full'.format(name)], 'o', label='Full {}'.format(name))
ax.plot(data['A']+2500, data['E_{}_repr'.format(name)], 's', label='Repr {}'.format(name))
ax.legend()
#ax.set_ylim(0, None)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook 

name = 'C_elec'

width = 7500
fig, ax = plt.subplots()
for i, row in data.iterrows():
    ax.add_line(plt.Line2D(xdata=[25000, 25000+width], ydata=[row['{}_full'.format(name)], 
              row['{}_repr'.format(name)]], linestyle='-', linewidth=0.5))
ax.hlines(0.975*data['{}_full'.format(name)].iloc[0], xmin=0, xmax=110000, linestyles=':')
ax.hlines(1.075*data['{}_full'.format(name)].iloc[0], xmin=0, xmax=110000, linestyles=':')


ax.plot([25000]*48, data['{}_full'.format(name)], 'o', label='Full {}'.format(name))
ax.plot([25000+width]*48, data['{}_repr'.format(name)], 's', label='Repr {}'.format(name))
ax.legend()
#ax.set_ylim(0, None)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook 

name = 'C_elec'

width = 7500
fig, ax = plt.subplots()
for i, row in data.iterrows():
    ax.add_line(plt.Line2D(xdata=[row['A'], row['A']+width], ydata=[row['{}_full'.format(name)], 
              row['{}_repr'.format(name)]], linestyle='-', linewidth=0.5))
ax.hlines(0.975*data['{}_full'.format(name)].iloc[0], xmin=0, xmax=110000, linestyles=':')
ax.hlines(1.075*data['{}_full'.format(name)].iloc[0], xmin=0, xmax=110000, linestyles=':')


ax.plot(data['A'], data['{}_full'.format(name)], 'o', label='Full {}'.format(name))
ax.plot(data['A']+width, data['{}_repr'.format(name)], 's', label='Repr {}'.format(name))
ax.legend()
#ax.set_ylim(0, None)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
pd.concat([repr_dem, repr_prod], axis=1).plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-65fb1b8c09fa> in <module>()
#       1 get_ipython().magic(u'matplotlib notebook')
# ----> 2 pd.concat([repr_dem, repr_prod], axis=1).plot()
#
# NameError: name 'repr_dem' is not defined

# %% [markdown]
# ## Cross check data

# %%
import modesto.utils as utils
import TimeSliceSelection.DataCollection as dc
from pkg_resources import resource_filename

datapath = resource_filename('modesto', 'Data')


sol_data_modesto = utils.read_time_data(datapath, 
                                        name='RenewableProduction/NewSolarThermal_TSS.csv', 
                                        expand=False).resample('1H').mean()
sol_data_tss =  dc.read_solar(time_step=1)

print sol_data_modesto.head()

# %matplotlib notebook
fig, ax = plt.subplots()
ax.plot(sol_data_modesto['0_40'], label='Mod')
ax.plot(sol_data_tss, label='TSS')

ax.legend()
# Out:
#                      0_0  0_40  -30_40  30_40
# Date
# 2014-01-01 00:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 01:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 02:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 03:00:00  0.0   0.0     0.0    0.0
# 2014-01-01 04:00:00  0.0   0.0     0.0    0.0
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
fig, ax = plt.subplots()

time_step=1
heat_tw_data_modesto = utils.read_time_data(datapath, 
                                        name='HeatDemand/HeatDemandFiltered.csv', 
                                        expand=False)['TermienEast']
heat_tw_data_tss =  dc.read_heat('HeatDemandFiltered', neighborhood='TermienEast',
                                          time_step=time_step)

ax.plot(heat_tw_data_modesto)
ax.plot(heat_tw_data_tss)
# Out:
# <img src="data:image/png;base64,..." width="640">

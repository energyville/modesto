# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('results/1dnewsol/result16p.txt', sep=' ', index_col=0)

# %%
data
# Out:
#           A      VSTC      VWat  E_backup_full  E_backup_repr  \
# 0   25000.0  100000.0   50000.0   1.777809e+08   1.818085e+08
# 1   25000.0  150000.0   50000.0   1.778220e+08   1.818482e+08
# 2   25000.0  200000.0   50000.0   1.778587e+08   1.818836e+08
# 3   50000.0  100000.0   50000.0   1.693566e+08   1.772604e+08
# 4   50000.0  150000.0   50000.0   1.693974e+08   1.772991e+08
# 5   50000.0  200000.0   50000.0   1.694339e+08   1.773336e+08
# 6   75000.0  100000.0   50000.0   1.609388e+08   1.742772e+08
# 7   75000.0  150000.0   50000.0   1.609785e+08   1.743149e+08
# 8   75000.0  200000.0   50000.0   1.610142e+08   1.743486e+08
# 9   25000.0  100000.0   75000.0   1.778086e+08   1.818336e+08
# 10  25000.0  150000.0   75000.0   1.778498e+08   1.818732e+08
# 11  25000.0  200000.0   75000.0   1.778865e+08   1.819086e+08
# 12  50000.0  100000.0   75000.0   1.693844e+08   1.772848e+08
# 13  50000.0  150000.0   75000.0   1.694252e+08   1.773235e+08
# 14  50000.0  200000.0   75000.0   1.694617e+08   1.773580e+08
# 15  75000.0  100000.0   75000.0   1.609667e+08   1.743010e+08
# 16  75000.0  150000.0   75000.0   1.610063e+08   1.743388e+08
# 17  75000.0  200000.0   75000.0   1.610421e+08   1.743725e+08
# 18  25000.0  100000.0  100000.0   1.778340e+08   1.818559e+08
# 19  25000.0  150000.0  100000.0   1.778752e+08   1.818956e+08
# 20  25000.0  200000.0  100000.0   1.779119e+08   1.819310e+08
# 21  50000.0  100000.0  100000.0   1.694098e+08   1.773066e+08
# 22  50000.0  150000.0  100000.0   1.694507e+08   1.773453e+08
# 23  50000.0  200000.0  100000.0   1.694872e+08   1.773798e+08
# 24  75000.0  100000.0  100000.0   1.609921e+08   1.743223e+08
# 25  75000.0  150000.0  100000.0   1.610318e+08   1.743601e+08
# 26  75000.0  200000.0  100000.0   1.610675e+08   1.743937e+08
# 27  25000.0  100000.0  125000.0   1.778578e+08   1.818764e+08
# 28  25000.0  150000.0  125000.0   1.778989e+08   1.819161e+08
# 29  25000.0  200000.0  125000.0   1.779356e+08   1.819515e+08
# 30  50000.0  100000.0  125000.0   1.694334e+08   1.773266e+08
# 31  50000.0  150000.0  125000.0   1.694744e+08   1.773653e+08
# 32  50000.0  200000.0  125000.0   1.695110e+08   1.773998e+08
# 33  75000.0  100000.0  125000.0   1.610150e+08   1.743418e+08
# 34  75000.0  150000.0  125000.0   1.610556e+08   1.743796e+08
# 35  75000.0  200000.0  125000.0   1.610913e+08   1.744132e+08
#
#     E_loss_stor_full  E_loss_stor_repr  E_curt_full   E_curt_repr  \
# 0      314126.121061     306577.876423          0.0  1.620897e+06
# 1      355221.116671     347636.046514          0.0  1.622236e+06
# 2      391881.518647     384256.335696          0.0  1.617991e+06
# 3      316329.453406     306578.010173          0.0  5.543589e+06
# 4      357092.168908     347636.164511          0.0  5.541015e+06
# 5      393542.395964     384256.466444          0.0  5.538584e+06
# 6      325004.243034     306578.065804          0.0  1.083714e+07
# 7      364608.686178     347636.212184          0.0  1.083340e+07
# 8      400331.942892     384256.493282          0.0  1.083005e+07
# 32   1.876384e+08    769321.636933     1.291988e+06    672431.599032
# 33   1.876384e+08    760280.097721     1.774759e+06    675106.358513
# 34   1.876384e+08    760274.585419     1.774288e+06    675060.850936
# 35   1.876384e+08    760309.257158     1.774537e+06    675050.574098
#
#     E_net_pump_repr
# 0     902346.871991
# 1     902445.637053
# 2     902533.977857
# 3     902807.307545
# 4     902901.954622
# 5     902986.632548
# 6     903557.363247
# 7     903652.039499
# 8     903736.791212
# 9     902537.148136
# 10    902635.913201
# 11    902724.254007
# 12    902994.985059
# 13    903089.636117
# 14    903174.319281
# 15    903745.136508
# 16    903839.816741
# 17    903924.573692
# 18    902706.826330
# 19    902805.591397
# 20    902893.932205
# 21    903162.352079
# 22    903257.005193
# 23    903341.688359
# 24    903912.588889
# 25    904007.271178
# 26    904092.028148
# 27    902862.677685
# 28    902961.442755
# 29    903049.783564
# 30    903316.082477
# 31    903410.735589
# 32    903495.418756
# 33    904066.397675
# 34    904161.079966
# 35    904245.836920

# %%
data['Full_dem'] = data[['E_demand_full', 'E_loss_stor_full', 'E_net_loss_full']].sum(axis=1)

# %%
data['Full_prod'] = data[['E_sol_full', 'E_backup_full']].sum(axis=1)

# %%
data['Repr_dem'] = data[['E_demand_repr', 'E_loss_stor_repr', 'E_net_loss_repr']].sum(axis=1)
data['Repr_prod'] = data[['E_sol_repr', 'E_backup_repr']].sum(axis=1)

# %%
# %matplotlib notebook

offset = 2500

plt.plot(data['A'], data['Full_dem'], 'o', label='Full dem side')
plt.plot(data['A']+offset, data['Full_prod'], 'o', label='Full prod side')
plt.plot(data['A'], data['Repr_dem'], 's', label='Repr dem side')
plt.plot(data['A']+offset, data['Repr_prod'], 's', label='Repr prod side')
plt.hlines([data['Full_dem'].mean()*0.975, data['Full_dem'].mean()*1.025], xmin=20000, xmax=80000, linestyles=':')
plt.plot(data['A'], data['E_demand_full'], '^', label='Full demand')
plt.plot(data['A'], data['E_demand_repr'], '^', label='Repr demand')
plt.plot(data['A']+offset, data['E_curt_repr'], )
plt.legend()
plt.ylim(0,None)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 200394795.66261107)

# %%
# %matplotlib notebook 

name = 'backup'
fig, ax = plt.subplots()
for i, row in data.iterrows():
    ax.add_line(plt.Line2D(xdata=[row['A'], row['A']+2500], ydata=[row['E_{}_full'.format(name)], 
              row['E_{}_repr'.format(name)]], linestyle='-', linewidth=0.5))
    
ax.plot(data['A'], data['E_{}_full'.format(name)], 'o', label='Full {}'.format(name))
ax.plot(data['A']+2500, data['E_{}_repr'.format(name)], 's', label='Repr {}'.format(name))
ax.legend()
ax.set_ylim(0, None)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 183002138.5029316)

# %%
# %matplotlib notebook 

name = 'sol'
fig, ax = plt.subplots()
for i, row in data.iterrows():
    ax.add_line(plt.Line2D(xdata=[row['A'], row['A']+2500], ydata=[row['E_{}_full'.format(name)], 
              row['E_{}_repr'.format(name)]], linestyle='-', linewidth=0.5))
    
ax.plot(data['A'], data['E_{}_full'.format(name)], 'o', label='Full {}'.format(name))
ax.plot(data['A']+2500, data['E_{}_repr'.format(name)], 's', label='Repr {}'.format(name))
ax.legend()
ax.set_ylim(0, None)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 26162174.696671505)

# %%
# %matplotlib notebook
pd.concat([repr_dem, repr_prod], axis=1).plot()

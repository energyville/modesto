000000055, 1.3590350000000058, 1.248718999999994, 1.217000999999982, 1.228904, 1.353283000000033, 1.2805550000000494, 1.2446580000000154, 1.2334410000000275, 1.35952199999997, 1.2511749999999893, 1.3355960000000096, 1.238157000000001, 1.2378330000000233, 1.3827370000000199, 1.2532019999999875, 1.2372210000000337, 1.247323999999992], 12: [3.169363999999973, 1.7195350000000076, 1.7130030000000147, 1.87620000000004, 1.7134630000000468, 1.7258519999999749, 1.8807890000000496, 1.716054999999983, 1.7393109999999297, 1.8646889999999985, 1.7188170000000014, 1.7261990000000085, 1.8764230000000448, 1.8724280000000133, 1.8334820000000605, 2.0174789999999234, 1.721254999999985, 1.9068200000000388, 1.7144349999999804, 1.6996929999999681, 1.882030999999984, 1.726178999999945, 1.7462629999999422, 1.9241670000000115, 1.713907000000006, 1.7235989999999788, 1.9375430000000617, 1.7283910000000446, 1.7346939999999904, 1.9161820000000491, 1.736921999999936, 1.7243080000000075, 1.9102309999999532, 1.7256390000000008, 1.7417610000000536, 1.868783000000008, 1.721770000000049, 1.7448210000000015, 1.9083580000000209, 1.7180880000000232, 1.8182250000000408, 1.8804009999999491, 1.7126950000000534, 1.8866930000000368, 1.7127699999999209, 1.743781999999953, 1.919967999999983, 1.7147009999999911], 16: [3.940204999999992, 2.2601520000000046, 2.47024399999998, 2.2441840000000184, 2.4382499999999823, 2.2601290000000627, 2.396501000000057, 2.253351000000009, 2.452635999999984, 2.1952170000000137, 2.213112000000024, 2.4523700000000304, 2.2164359999999874, 2.413033999999982, 2.2155410000000 ...

# %%
data_ref = pd.read_csv('refresult.txt', sep=' ', index_col=0)

# %%
times['Full'] = data_ref['t_full'].values.tolist()

# %%
#labels = ['Full', 10, 9, 8,7,6,5,4]
labels = ['Full', 32, 24, 20, 16, 12, 8]
datals = [times[lab] for lab in labels]
box = plt.boxplot(datals, labels=labels)
plt.xlabel('Number of days')
plt.ylabel('Calculation time [s]')
#plt.ylim(0,35)
plt.grid(alpha=0.3, linestyle=':')
plt.tight_layout()
plt.savefig('BoxplotCalcTime1d.png', dpi=400)

# %%
box
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x122423610>,
#   <matplotlib.lines.Line2D at 0x12242cd10>,
#   <matplotlib.lines.Line2D at 0x1224437d0>,
#   <matplotlib.lines.Line2D at 0x12245c290>,
#   <matplotlib.lines.Line2D at 0x122467d10>,
#   <matplotlib.lines.Line2D at 0x12247e7d0>,
#   <matplotlib.lines.Line2D at 0x122496290>],
#  'caps': [<matplotlib.lines.Line2D at 0x122423e50>,
#   <matplotlib.lines.Line2D at 0x12242c250>,
#   <matplotlib.lines.Line2D at 0x122438910>,
#   <matplotlib.lines.Line2D at 0x122438cd0>,
#   <matplotlib.lines.Line2D at 0x1224503d0>,
#   <matplotlib.lines.Line2D at 0x122450790>,
#   <matplotlib.lines.Line2D at 0x12245ce50>,
#   <matplotlib.lines.Line2D at 0x122467250>,
#   <matplotlib.lines.Line2D at 0x122473910>,
#   <matplotlib.lines.Line2D at 0x122473cd0>,
#   <matplotlib.lines.Line2D at 0x12248b3d0>,
#   <matplotlib.lines.Line2D at 0x12248b790>,
#   <matplotlib.lines.Line2D at 0x122496e50>,
#   <matplotlib.lines.Line2D at 0x1224a2250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12242c9d0>,
#   <matplotlib.lines.Line2D at 0x122443490>,
#   <matplotlib.lines.Line2D at 0x122450f10>,
#   <matplotlib.lines.Line2D at 0x1224679d0>,
#   <matplotlib.lines.Line2D at 0x12247e490>,
#   <matplotlib.lines.Line2D at 0x12248bf10>,
#   <matplotlib.lines.Line2D at 0x1224a29d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x12242c610>,
#   <matplotlib.lines.Line2D at 0x1224430d0>,
#   <matplotlib.lines.Line2D at 0x122450b50>,
#   <matplotlib.lines.Line2D at 0x122467610>,
#   <matplotlib.lines.Line2D at 0x12247e0d0>,
#   <matplotlib.lines.Line2D at 0x12248bb50>,
#   <matplotlib.lines.Line2D at 0x1224a2610>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1224236d0>,
#   <matplotlib.lines.Line2D at 0x122423a90>,
#   <matplotlib.lines.Line2D at 0x122438190>,
#   <matplotlib.lines.Line2D at 0x122438550>,
#   <matplotlib.lines.Line2D at 0x122443c10>,
#   <matplotlib.lines.Line2D at 0x122443fd0>,
#   <matplotlib.lines.Line2D at 0x12245c6d0>,
#   <matplotlib.lines.Line2D at 0x12245ca90>,
#   <matplotlib.lines.Line2D at 0x122473190>,
#   <matplotlib.lines.Line2D at 0x122473550>,
#   <matplotlib.lines.Line2D at 0x12247ec10>,
#   <matplotlib.lines.Line2D at 0x12247efd0>,
#   <matplotlib.lines.Line2D at 0x1224966d0>,
#   <matplotlib.lines.Line2D at 0x122496a90>]}

# %%
import numpy as np

full = np.mean(times['Full'])

ratios = [full/np.mean(times[ident]) for ident in [32, 24, 20, 16, 12, 8]]
print ratios
# Out:
# [10.935547164428867, 15.136638656411279, 17.772918594335103, 22.23959418723256, 28.878936986484106, 39.98497350491086]

# %%
plt.boxplot(ratios)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x122515290>],
#  'caps': [<matplotlib.lines.Line2D at 0x122515ad0>,
#   <matplotlib.lines.Line2D at 0x122515e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12251f650>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x12251f290>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x122515350>,
#   <matplotlib.lines.Line2D at 0x122515710>]}

# %%
np.mean(ratios)
# Out:
# 22.49143484896713

# %%
np.max(ratios)
# Out:
# 39.98497350491086

# %%
np.min(ratios)
# Out:
# 10.935547164428867

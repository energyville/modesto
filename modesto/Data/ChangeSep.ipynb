# %%
import os
import pandas as pd

# %% [markdown]
# ## Settings

# %%
extensionold = '.txt'  # Extension to read
extensionnew = '.csv' # Extension to be written
sepold = ' '  # Separator to be replaced
sepnew = ';'

removeOld = True 

ignore = ['readme.txt'] # Files to ignore

# %%
for dirpath, dirnames, filenames in os.walk('../Data/'):
    print(dirpath)
    print(filenames)
    for filename in filenames:
        print(os.path.join(dirpath, filename))
        if filename.endswith(extensionold) and not filename in ignore:
            newfilename = os.path.splitext(filename)[0]+extensionnew
            data = pd.read_csv(os.path.join(dirpath, filename), parse_dates=True, sep= sepold, index_col=0)
            data.to_csv(os.path.join(dirpath,newfilename), sep=sepnew)
            if removeOld:
                os.remove(os.path.join(dirpath,filename))
    print('------------------------------------------------------------')
    print('')
# Out:
# ../Data/
# ['ChangeSep.ipynb']
# ../Data/ChangeSep.ipynb
# ------------------------------------------------------------
#
# ../Data/.ipynb_checkpoints
# ['ChangeSep-checkpoint.ipynb']
# ../Data/.ipynb_checkpoints\ChangeSep-checkpoint.ipynb
# ------------------------------------------------------------
#
# ../Data/ElectricityPrices
# ['DAM_electricity_prices-2014_BE.csv', 'DAM_prices_and_volumes_hourly.csv']
# ../Data/ElectricityPrices\DAM_electricity_prices-2014_BE.csv
# ../Data/ElectricityPrices\DAM_prices_and_volumes_hourly.csv
# ------------------------------------------------------------
#
# ../Data/HeatDemand
# ['HeatDemand.csv', 'HeatDemand.txt', 'HeatDemandFiltered.csv', 'HeatDemandFiltered.txt']
# ../Data/HeatDemand\HeatDemand.csv
# ../Data/HeatDemand\HeatDemand.txt
# ../Data/HeatDemand\HeatDemandFiltered.csv
# ../Data/HeatDemand\HeatDemandFiltered.txt
# ------------------------------------------------------------
#
# ../Data/HeatDemand\60min
# []
# ------------------------------------------------------------
#
# ../Data/HeatDemand\Initialized
# ['HeatDemand.csv', 'HeatDemand.txt', 'HeatDemandFiltered.csv', 'HeatDemandFiltered.txt']
# ../Data/HeatDemand\Initialized\HeatDemand.csv
# ../Data/HeatDemand\Initialized\HeatDemand.txt
# ../Data/HeatDemand\Initialized\HeatDemandFiltered.csv
# ../Data/HeatDemand\Initialized\HeatDemandFiltered.txt
# ------------------------------------------------------------
#
# ../Data/PipeCatalog
# ['IsoPlusDoubleReinforced.csv', 'IsoPlusDoubleReinforced.txt', 'IsoPlusDoubleStandard.csv', 'IsoPlusDoubleStandard.txt', 'readme.txt', 'RigidSingleCompound.csv', 'RigidSingleCompound.txt', 'RigidSingleCompoundReinforced.csv', 'RigidSingleCompoundReinforced.txt']
# ../Data/PipeCatalog\IsoPlusDoubleReinforced.csv
# ../Data/PipeCatalog\IsoPlusDoubleReinforced.txt
# ../Data/PipeCatalog\IsoPlusDoubleStandard.csv
# ../Data/PipeCatalog\IsoPlusDoubleStandard.txt
# ../Data/PipeCatalog\readme.txt
# ../Data/PipeCatalog\RigidSingleCompound.csv
# ../Data/PipeCatalog\RigidSingleCompound.txt
# ../Data/PipeCatalog\RigidSingleCompoundReinforced.csv
# ../Data/PipeCatalog\RigidSingleCompoundReinforced.txt
# ------------------------------------------------------------
#
# ../Data/RenewableProduction
# ['SolarThermal.csv', 'SolarThermal.txt', 'SolarThermalNew.csv', 'SolarThermalNew.txt']
# ../Data/RenewableProduction\SolarThermal.csv
# ../Data/RenewableProduction\SolarThermal.txt
# ../Data/RenewableProduction\SolarThermalNew.csv
# ../Data/RenewableProduction\SolarThermalNew.txt
# ------------------------------------------------------------
#
# ../Data/RenewableProduction\60min
# []
# ------------------------------------------------------------
#
# ../Data/Weather
# ['extT.csv', 'extT.txt']
# ../Data/Weather\extT.csv
# ../Data/Weather\extT.txt
# ------------------------------------------------------------
#
# ../Data/Weather\60min
# []
# ------------------------------------------------------------

# %%
import modesto.Examples.example as mot
from pyomo.core.base import value
# Out:
# 01-08 09:00 matplotlib.pyplot                    DEBUG    Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
optmodel= mot.construct_model()
# Out:
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Te
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Q_sol_E
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Q_sol_S
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Q_sol_W
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Q_sol_N
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lines
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter CO2_price
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF_el
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter elec_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lines
# 01-08 09:00 modesto.Node                         INFO     Initializing Node ThorPark
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter efficiency
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter CO2
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fuel_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Qmax
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Qmin
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter ramp
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter ramp_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter CO2_price
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 01-08 09:00 modesto.component.Component          INFO     Initializing Component ThorPark.plant
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter efficiency
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter CO2
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fuel_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Qmax
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Qmin
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter ramp
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter ramp_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter CO2_price
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 01-08 09:00 modesto.components.VarProducer       INFO     Initializing VarProducer ThorPark.plant
# 01-08 09:00 modesto.Node                         INFO     Component ThorPark.plant added to ThorPark
# 01-08 09:00 modesto.Node                         INFO     Build of ThorPark finished
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lines
# 01-08 09:00 modesto.Node                         INFO     Initializing Node p1
# 01-08 09:00 modesto.Node                         INFO     Build of p1 finished
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lines
# 01-08 09:00 modesto.Node                         INFO     Initializing Node waterscheiGarden
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 01-08 09:00 modesto.component.Component          INFO     Initializing Component waterscheiGarden.buildingD
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 01-08 09:00 modesto.Node                         INFO     Component waterscheiGarden.buildingD added to waterscheiGarden
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Thi
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tlo
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mflo_max
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mflo_min
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter volume
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter ar
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter dIns
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter kIns
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter heat_stor
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mflo_use
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Te
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.component.Component          INFO     Initializing Component waterscheiGarden.storage
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Thi
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tlo
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mflo_max
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mflo_min
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter volume
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter ar
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter dIns
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter kIns
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter heat_stor
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mflo_use
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Te
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.Node                         INFO     Component waterscheiGarden.storage added to waterscheiGarden
# 01-08 09:00 modesto.Node                         INFO     Build of waterscheiGarden finished
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lines
# 01-08 09:00 modesto.Node                         INFO     Initializing Node zwartbergNE
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 01-08 09:00 modesto.component.Component          INFO     Initializing Component zwartbergNE.buildingD
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 01-08 09:00 modesto.Node                         INFO     Component zwartbergNE.buildingD added to zwartbergNE
# 01-08 09:00 modesto.Node                         INFO     Build of zwartbergNE finished
# 01-08 09:00 modesto.Edge                         INFO     Initializing Edge bbThor
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF_el
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_mech
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_elmo
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter elec_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.component.Component          INFO     Initializing Component bbThor
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF_el
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_mech
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_elmo
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter elec_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.Edge                         INFO     Pipe model SimplePipe added to bbThor
# 01-08 09:00 modesto.Edge                         INFO     Initializing Edge spWaterschei
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF_el
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_mech
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_elmo
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter elec_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.component.Component          INFO     Initializing Component spWaterschei
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF_el
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_mech
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_elmo
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter elec_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.Edge                         INFO     Pipe model SimplePipe added to spWaterschei
# 01-08 09:00 modesto.Edge                         INFO     Initializing Edge spZwartbergNE
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF_el
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_mech
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_elmo
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter elec_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.component.Component          INFO     Initializing Component spZwartbergNE
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter time_step
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter horizon
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter PEF_el
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_mech
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter eta_elmo
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter elec_cost
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter lifespan
# 01-08 09:00 modesto.parameter.Parameter          INFO     Initializing Parameter fix_maint
# 01-08 09:00 modesto.Edge                         INFO     Pipe model SimplePipe added to spZwartbergNE
# 01-08 09:00 modesto.parameter.Parameter          INFO     Changing value in parameter time_step. Model needs to be recompiled for changes to take effect.
# 01-08 09:00 modesto.parameter.Parameter          INFO     Changing value in parameter horizon. Model needs to be recompiled for changes to take effect.
# 01-08 09:00 modesto.parameter.Parameter          INFO     Changing value in parameter heat_stor. Model needs to be recompiled for changes to take effect.
# 01-08 09:00 modesto.parameter.Parameter          INFO     Changing value in parameter efficiency. Model needs to be recompiled for changes to take effect.
# 01-08 09:00 modesto.parameter.Parameter          INFO     Changing value in parameter PEF. Model needs to be recompiled for changes to take effect.
# 01-08 09:00 modesto.parameter.Parameter          INFO     Changing value in parameter CO2. Model needs to be recompiled for changes to take effect.
# 01-08 09:00 modesto.parameter.Parameter          INFO     Changing value in parameter ramp_cost. Model needs to be recompiled for changes to take effect.
# 01-08 09:00 modesto.parameter.Parameter          INFO     Changing value in parameter ramp. Model needs to be recompiled for changes to take effect.

# %%
optmodel.compile(start_time='20140101')
# Out:
# 01-08 09:00 modesto.component.Component          INFO     Optimization block initialized for bbThor
# 01-08 09:00 modesto.component.Component          INFO     Optimization block initialized for spWaterschei
# 01-08 09:00 modesto.component.Component          INFO     Optimization block initialized for spZwartbergNE
# 01-08 09:00 modesto.Node                         INFO     Optimization block initialized for ThorPark
# 01-08 09:00 modesto.components.VarProducer       INFO     Optimization block initialized for ThorPark.plant
# 01-08 09:00 modesto.Node                         INFO     Compilation of ThorPark finished
# 01-08 09:00 modesto.Node                         INFO     Optimization block initialized for p1
# 01-08 09:00 modesto.Node                         INFO     Compilation of p1 finished
# 01-08 09:00 modesto.Node                         INFO     Optimization block initialized for waterscheiGarden
# 01-08 09:00 modesto.component.Component          INFO     Optimization block initialized for waterscheiGarden.buildingD
# 01-08 09:00 modesto.component.Component          INFO     Optimization model <class 'modesto.component.BuildingFixed'> waterscheiGarden.buildingD compiled
# 01-08 09:00 modesto.component.Component          INFO     Optimization block initialized for waterscheiGarden.storage
# 01-08 09:00 modesto.component.Component          INFO     Optimization model Storage waterscheiGarden.storage compiled
# 01-08 09:00 modesto.Node                         INFO     Compilation of waterscheiGarden finished
# 01-08 09:00 modesto.Node                         INFO     Optimization block initialized for zwartbergNE
# 01-08 09:00 modesto.component.Component          INFO     Optimization block initialized for zwartbergNE.buildingD
# 01-08 09:00 modesto.component.Component          INFO     Optimization model <class 'modesto.component.BuildingFixed'> zwartbergNE.buildingD compiled
# 01-08 09:00 modesto.Node                         INFO     Compilation of zwartbergNE finished

# %%
optmodel.set_objective('energy')
# Out:
# 01-08 09:00 modesto.main.Modesto                 DEBUG    energy objective set

# %%
optmodel.solve()
# Out:
# 01-08 09:00 modesto.main.Modesto                 INFO     Model solved.
# 0

# %%
print((optmodel.get_objective('energy')))
print((optmodel.get_objective('co2')))
# Out:
# 5715117.810813161
# 1017290.970324742

# %%
for obj in optmodel.objectives:
    print((obj, ':', optmodel.objectives[obj].active))
# Out:
# energy : True
# cost : False
# cost_ramp : False
# co2 : False
# cost_fuel_co2 : False

# %%
optmodel.get_objective()
# Out:
# 5715117.810813161

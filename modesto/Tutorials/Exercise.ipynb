# %% [markdown]
# # modesto tutorial

# %% [markdown]
# This tutorial shows how to let modesto solve a simple network.

# %% [markdown]
# ## Imports and other stuff

# %%
from __future__ import division

import logging
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import modesto.utils as ut
from modesto.main import Modesto

# %%
# %matplotlib notebook

# %%
logging.basicConfig(level=logging.ERROR,
                    format='%(asctime)s %(name)-36s %(levelname)-8s %(message)s',
                    datefmt='%m-%d %H:%M')
logger = logging.getLogger('Main.py')

# %% [markdown]
# ## Network graph

# %% [markdown]
# A first step is to make a networkX object of the network you would like to optimize:
#
# For the model to load correctly into modesto, you need to add some attributes to each of the nodes and edges.
#
# For the nodes (besides the name of the node):
# * **x, y, and z**: coordinates of the node in meter
# * **comps**: a dictionary containing all components (except the network pipes) that are connected to the nodes. The keys of the dictionary are the names of the components, the values are the types of the components.
#
# For the edges (besides names of the nodes where the edge starts and stops):
# * **Name of the edge**

# %%
G = nx.DiGraph()

G.add_node('ElectricityNetwork', x=0, y=0, z=0,
           comps={'plants': 'ProducerVariable'})

G.add_node('CondensingGasBoilers', x=1, y=1, z=0,
           comps={'buildings': 'BuildingFixed'})
G.add_edge('ElectricityNetwork', 'CondensingGasBoilers', name='line1')

G.add_node('HeatPumps', x=1, y=0, z=0,
           comps={'buildings': 'BuildingFixed'})
G.add_edge('ElectricityNetwork', 'HeatPumps', name='line2')

G.add_node('FlexibleHeatPumps', x=1, y=-1, z=0,
           comps={'buildings': 'RCmodel'})
G.add_edge('ElectricityNetwork', 'FlexibleHeatPumps', name='line3')
                  
G.add_node('SolarPanels', x=0, y=1, z=0,
           comps={'panels': 'ProducerFixed'})
G.add_edge('ElectricityNetwork', 'SolarPanels', name='line4')

G.add_node('OnshoreWind', x=0, y=-1, z=0,
           comps={'turbines': 'ProducerFixed'})
G.add_edge('ElectricityNetwork', 'OnshoreWind', name='line5')

G.add_node('OffshoreWind', x=-1, y=1, z=0,
           comps={'turbines': 'ProducerFixed'})
G.add_edge('ElectricityNetwork', 'OffshoreWind', name='line6')

G.add_node('CCGT', x=-1, y=0, z=0,
           comps={'plants': 'ProducerVariable'})
G.add_edge('ElectricityNetwork', 'CCGT', name='line7')

G.add_node('OCGT', x=-1, y=1, z=0,
           comps={'plants': 'ProducerVariable'})
G.add_edge('ElectricityNetwork', 'OCGT', name='line8')
                  
    
nx.draw(G, with_labels=True, font_weight='bold')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Setting up modesto

# %% [markdown]
# Decide the following characteristics of the optimization problem:
# * **Horizon** of the optimization problem (in seconds)
# * **Time step** of the (discrete) problem (in seconds)
# * **Start time** (should be a pandas TimeStamp). Currently, weather and prixe data for 2014 are available in modesto.
# * **Pipe model**: The type of model used to model the pipes. Only one type can be selected for the whole optimization problem (unlike the component model types). Possibilities: SimplePipe (= perfect pipe, no losses, no time delays), ExtensivePipe (limited mass flows and heat losses, no time delays) and NodeMethod (heat losses and time delays, but requires mass flow rates to be known in advance)

# %%
horizon = 5*24*3600
time_step = 3600
start_time = pd.Timestamp('20140104')
pipe_model = 'SimplePipe'

# %% [markdown]
# And create the modesto object

# %%
optmodel = Modesto(horizon=horizon, 
                   time_step=time_step,
                   pipe_model=pipe_model, 
                   graph=G)
# Out:
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Te
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 04-13 13:41 modesto.Node                         INFO     Initializing Node ElectricityNetwork
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component plants
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter efficiency
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter PEF
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter CO2
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter fuel_cost
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Qmax
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter ramp
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter ramp_cost
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.components.VarProducer       INFO     Initializing VarProducer plants
# 04-13 13:41 modesto.Node                         INFO     Component plants added to ElectricityNetwork
# 04-13 13:41 modesto.Node                         INFO     Build of ElectricityNetwork finished
# 04-13 13:41 modesto.Node                         INFO     Initializing Node OnshoreWind
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component turbines
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 04-13 13:41 modesto.Node                         INFO     Component turbines added to OnshoreWind
# 04-13 13:41 modesto.Node                         INFO     Build of OnshoreWind finished
# 04-13 13:41 modesto.Node                         INFO     Initializing Node OffshoreWind
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component turbines
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 04-13 13:41 modesto.Node                         INFO     Component turbines added to OffshoreWind
# 04-13 13:41 modesto.Node                         INFO     Build of OffshoreWind finished
# 04-13 13:41 modesto.Node                         INFO     Initializing Node HeatPumps
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component buildings
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 04-13 13:41 modesto.Node                         INFO     Component buildings added to HeatPumps
# 04-13 13:41 modesto.Node                         INFO     Build of HeatPumps finished
# 04-13 13:41 modesto.Node                         INFO     Initializing Node CondensingGasBoilers
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component buildings
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 04-13 13:41 modesto.Node                         INFO     Component buildings added to CondensingGasBoilers
# 04-13 13:41 modesto.Node                         INFO     Build of CondensingGasBoilers finished
# 04-13 13:41 modesto.Node                         INFO     Initializing Node SolarPanels
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component panels
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter heat_profile
# 04-13 13:41 modesto.Node                         INFO     Component panels added to SolarPanels
# 04-13 13:41 modesto.Node                         INFO     Build of SolarPanels finished
# 04-13 13:41 modesto.Node                         INFO     Initializing Node OCGT
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component plants
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter efficiency
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter PEF
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter CO2
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter fuel_cost
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Qmax
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter ramp
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter ramp_cost
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.components.VarProducer       INFO     Initializing VarProducer plants
# 04-13 13:41 modesto.Node                         INFO     Component plants added to OCGT
# 04-13 13:41 modesto.Node                         INFO     Build of OCGT finished
# 04-13 13:41 modesto.Node                         INFO     Initializing Node CCGT
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component plants
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter efficiency
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter PEF
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter CO2
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter fuel_cost
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Qmax
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter ramp
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter ramp_cost
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.components.VarProducer       INFO     Initializing VarProducer plants
# 04-13 13:41 modesto.Node                         INFO     Component plants added to CCGT
# 04-13 13:41 modesto.Node                         INFO     Build of CCGT finished
# 04-13 13:41 modesto.Node                         INFO     Initializing Node FlexibleHeatPumps
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component buildings
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TiD0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TflD0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TwiD0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TwD0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TfiD0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TiN0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TwiN0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TwN0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter TfiN0
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter delta_T
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter mult
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter model_type
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter day_max_temperature
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter day_min_temperature
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter night_max_temperature
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter night_min_temperature
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter bathroom_max_temperature
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter bathroom_min_temperature
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter bathroom_max_temperature
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter bathroom_min_temperature
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Q_sol_E
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Q_sol_S
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Q_sol_W
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Q_sol_N
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Q_int_D
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Q_int_N
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Te
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter Tg
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter max_heat
# 04-13 13:41 modesto.Node                         INFO     Component buildings added to FlexibleHeatPumps
# 04-13 13:41 modesto.Node                         INFO     Build of FlexibleHeatPumps finished
# 04-13 13:41 modesto.Edge                         INFO     Initializing Edge line5
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component line5
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# ElectricityNetwork
# OnshoreWind
# OffshoreWind
# HeatPumps
# CondensingGasBoilers
# SolarPanels
# OCGT
# CCGT
# FlexibleHeatPumps
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.Edge                         INFO     Pipe model SimplePipe added to line5
# 04-13 13:41 modesto.Edge                         INFO     Initializing Edge line6
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component line6
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.Edge                         INFO     Pipe model SimplePipe added to line6
# 04-13 13:41 modesto.Edge                         INFO     Initializing Edge line2
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component line2
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.Edge                         INFO     Pipe model SimplePipe added to line2
# 04-13 13:41 modesto.Edge                         INFO     Initializing Edge line1
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component line1
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.Edge                         INFO     Pipe model SimplePipe added to line1
# 04-13 13:41 modesto.Edge                         INFO     Initializing Edge line4
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component line4
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.Edge                         INFO     Pipe model SimplePipe added to line4
# 04-13 13:41 modesto.Edge                         INFO     Initializing Edge line8
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component line8
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.Edge                         INFO     Pipe model SimplePipe added to line8
# 04-13 13:41 modesto.Edge                         INFO     Initializing Edge line7
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component line7
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.Edge                         INFO     Pipe model SimplePipe added to line7
# 04-13 13:41 modesto.Edge                         INFO     Initializing Edge line3
# 04-13 13:41 modesto.component.Component          INFO     Initializing Component line3
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter diameter
# 04-13 13:41 modesto.parameter.Parameter          INFO     Initializing Parameter cost_inv
# 04-13 13:41 modesto.Edge                         INFO     Pipe model SimplePipe added to line3

# %% [markdown]
# ## Adding data

# %% [markdown]
# modesto is now aware of the position and interconnections between components, nodes and edges, but still needs information rergarding, weather, prices, customer demands, component sizing, etc.

# %% [markdown]
# ### Collect data

# %% [markdown]
# modesto provides some useful data handling methods (found in modesto.utils). Most notable is read_time_data, that can load time-variable data from a csv file. In this example, the data that is available in the folder modesto/Data is used.
#
# We use `pkg_resources` to access the example data directory included in the `modesto` library. However, you may also supply your own data, given that it can be transformed into a `pandas` DataFrame with a DatetimeIndex.

# %%
from pkg_resources import resource_filename

DATAPATH = resource_filename('modesto', 'Data')

# %% [markdown]
# #### Weather data:

# %%
weatherdata = ut.read_time_data(path=DATAPATH, name='Weather/weatherData.csv')

t_amb = weatherdata['Te']
t_g = weatherdata['Tg']
QsolN = weatherdata['QsolN']
QsolE = weatherdata['QsolE']
QsolS = weatherdata['QsolS']
QsolW = weatherdata['QsolW']
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-30-1ca271dcca0f> in <module>()
#       1 print ut.read_xlsx_data('C:\Users\u0111619\Desktop\oefenzitting_integrated_model\01_choice_hp_or_gasboiler',
# ----> 2                         use_sheet='year_data', index_col=0)
#       3
#       4 weatherdata = ut.read_time_data(path=DATAPATH, name='Weather/weatherData.csv')
#       5
#
# c:\users\u0111619\documents\python\modesto\modesto\utils.pyc in read_xlsx_data(filepath, use_sheet, index_col)
#      68     else:
#      69         sheet_name = use_sheet
# ---> 70     df = pd.read_excel(filepath, sheet_name=sheet_name, index_col=index_col)
#      71     return df
#      72
#
# c:\python27\lib\site-packages\pandas\util\_decorators.pyc in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# c:\python27\lib\site-packages\pandas\io\excel.pyc in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
#     229     if not isinstance(io, ExcelFile):
# --> 230         io = ExcelFile(io, engine=engine)
#     231
#     232     return io._parse_excel(
#
# c:\python27\lib\site-packages\pandas\io\excel.pyc in __init__(self, io, **kwds)
#     292             self.book = xlrd.open_workbook(file_contents=data)
#     293         elif isinstance(self._io, compat.string_types):
# --> 294             self.book = xlrd.open_workbook(self._io)
#     295         else:
#     296             raise ValueError('Must explicitly set engine if not passing in'
#
# c:\python27\lib\site-packages\xlrd\__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     114         peek = file_contents[:peeksz]
#     115     else:
# --> 116         with open(filename, "rb") as f:
#     117             peek = f.read(peeksz)
#     118     if peek == b"PK\x03\x04": # a ZIP file
#
# IOError: [Errno 22] invalid mode ('rb') or filename: 'C:\\Users\\u0111619\\Desktop\\oefenzitting_integrated_model\x01_choice_hp_or_gasboiler'

# %% [markdown]
# #### Building data

# %%
userprofile = ut.read_time_data(DATAPATH, name='UserBehaviour/ISO13790.csv')

day_max = userprofile['day_max']
day_min = userprofile['day_min']
night_max = userprofile['night_max']
night_min = userprofile['night_min']
bathroom_max = userprofile['bathroom_max']
bathroom_min = userprofile['bathroom_min']
floor_max = userprofile['floor_max']
floor_min = userprofile['floor_min']
Q_int_D = userprofile['Q_int_D']
Q_int_N = userprofile['Q_int_N']

# %% [markdown]
# #### Electricity price

# %%
c_f = ut.read_time_data(path=DATAPATH,name='ElectricityPrices/DAM_electricity_prices-2014_BE.csv')['price_BE']

# %% [markdown]
# ### Changing parameters

# %% [markdown]
# In order to solve the problem, all parameters of the optimization probkem need to get a value. A list of the parameters that modesto needs and their description can be found with the following command:

# %%
optmodel.print_all_params()
# Out:
# --- Building.building ---
#
# -TfiN0
# Description: Begin temperature at state TfiN
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -Q_sol_W
# Description: Western solar radiation
# Unit: W
#
# -Q_sol_S
# Description: Southern solar radiation
# Unit: W
#
# -Q_sol_N
# Description: Northern solar radiation
# Unit: W
#
# -bathroom_min_temperature
# Description: Minimum temperature for bathroom zones
# Unit: K
#
# -Q_int_D
# Description: Internal heat gains, day zones
# Unit: W
#
# -Tg
# Description: Undisturbed ground temperature
# Unit: K
#
# -Q_sol_E
# Description: Eastern solar radiation
# Unit: W
#
# -Te
# Description: Ambient temperature
# Unit: K
#
# -Q_int_N
# Description: Internal heat gains, night zones
# Unit: W
#
# -TwiD0
# Description: Begin temperature at state TwiD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -TwD0
# Description: Begin temperature at state TwD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -TfiD0
# Description: Begin temperature at state TfiD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -floor_max_temperature
# Description: Minimum temperature for bathroom zones
# Unit: K
#
# -TwiN0
# Description: Begin temperature at state TwiN
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -day_min_temperature
# Description: Minimum temperature for day zones
# Unit: K
#
# -night_max_temperature
# Description: Maximum temperature for night zones
# Unit: K
#
# -TiD0
# Description: Begin temperature at state TiD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -TflD0
# Description: Begin temperature at state TflD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -day_max_temperature
# Description: Maximum temperature for day zones
# Unit: K
#
# -mult
# Description: Number of buildings represented by building model
# Unit: -
#
# -night_min_temperature
# Description: Minimum temperature for night zones
# Unit: K
#
# -TiN0
# Description: Begin temperature at state TiN
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -delta_T
# Description: Temperature difference across substation
# Unit: K
#
# -bathroom_max_temperature
# Description: Minimum temperature for bathroom zones
# Unit: K
#
# -floor_min_temperature
# Description: Minimum temperature for bathroom zones
# Unit: K
#
# -max_heat
# Description: Maximum heating power through substation
# Unit: W
#
# -model_type
# Description: Type of building model to be used
# Unit: -
#
# -TwN0
# Description: Begin temperature at state TwN
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
#
# --- BuildingAndStorage.building ---
#
# -TfiN0
# Description: Begin temperature at state TfiN
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -Q_sol_W
# Description: Western solar radiation
# Unit: W
#
# -Q_sol_S
# Description: Southern solar radiation
# Unit: W
#
# -Q_sol_N
# Description: Northern solar radiation
# Unit: W
#
# -bathroom_min_temperature
# Description: Minimum temperature for bathroom zones
# Unit: K
#
# -Q_int_D
# Description: Internal heat gains, day zones
# Unit: W
#
# -Tg
# Description: Undisturbed ground temperature
# Unit: K
#
# -Q_sol_E
# Description: Eastern solar radiation
# Unit: W
#
# -Te
# Description: Ambient temperature
# Unit: K
#
# -Q_int_N
# Description: Internal heat gains, night zones
# Unit: W
#
# -TwiD0
# Description: Begin temperature at state TwiD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -TwD0
# Description: Begin temperature at state TwD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -TfiD0
# Description: Begin temperature at state TfiD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -floor_max_temperature
# Description: Minimum temperature for bathroom zones
# Unit: K
#
# -TwiN0
# Description: Begin temperature at state TwiN
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -day_min_temperature
# Description: Minimum temperature for day zones
# Unit: K
#
# -night_max_temperature
# Description: Maximum temperature for night zones
# Unit: K
#
# -TiD0
# Description: Begin temperature at state TiD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -TflD0
# Description: Begin temperature at state TflD
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -day_max_temperature
# Description: Maximum temperature for day zones
# Unit: K
#
# -mult
# Description: Number of buildings represented by building model
# Unit: -
#
# -night_min_temperature
# Description: Minimum temperature for night zones
# Unit: K
#
# -TiN0
# Description: Begin temperature at state TiN
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
# -delta_T
# Description: Temperature difference across substation
# Unit: K
#
# -bathroom_max_temperature
# Description: Minimum temperature for bathroom zones
# Unit: K
#
# -floor_min_temperature
# Description: Minimum temperature for bathroom zones
# Unit: K
#
# -max_heat
# Description: Maximum heating power through substation
# Unit: W
#
# -model_type
# Description: Type of building model to be used
# Unit: -
#
# -TwN0
# Description: Begin temperature at state TwN
# Unit: K
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: True
#
#
# --- BuildingAndStorage.storage ---
#
# -mflo_use
# Description: Use of warm water stored in the tank, replaced by cold water, e.g. DHW. standard is 0
# Unit: kg/s
#
# -mflo_max
# Description: Maximal mass flow rate to and from storage vessel
# Unit: kg/s
#
# -heat_stor
# Description: Heat stored in the thermal storage unit
# Unit: kWh
# InitType: fixedVal
# Upper bound: None
# Lower bound: None
# Slack: False
#
# -volume
# Description: Storage volume
# Unit: m3
#
# -ar
# Description: Aspect ratio (height/width)
# Unit: -
#
# -dIns
# Description: Insulation thickness
# Unit: m
#
# -kIns
# Description: Thermal conductivity of insulation material
# Unit: W/(m.K)
#
# -Thi
# Description: High temperature in tank
# Unit: K
#
# -mflo_min
# Description: Minimal mass flow rate to and from storage vessel
# Unit: kg/s
#
# -Tlo
# Description: Low temperature in tank
# Unit: K
#
#
# --- pipe1 ---
#
# -diameter
# Description: Pipe diameter
# Unit: DN (mm)
#
# -temperature_return
# Description: Return temperature
# Unit: K
#
# -temperature_supply
# Description: Supply temperature
# Unit: K
#
#
# --- pipe3 ---
#
# -diameter
# Description: Pipe diameter
# Unit: DN (mm)
#
# -temperature_return
# Description: Return temperature
# Unit: K
#
# -temperature_supply
# Description: Supply temperature
# Unit: K
#
#
# --- pipe2 ---
#
# -diameter
# Description: Pipe diameter
# Unit: DN (mm)
#
# -temperature_return
# Description: Return temperature
# Unit: K
#
# -temperature_supply
# Description: Supply temperature
# Unit: K
#
#
# --- Producer.plant ---
#
# -ramp_cost
# Description: Ramping cost
# Unit: euro/(W/s)
#
# -CO2
# Description: amount of CO2 released when using primary energy source
# Unit: kg/kWh
#
# -fuel_cost
# Description: cost of fuel/electricity to generate heat
# Unit: euro/kWh
#
# -ramp
# Description: Maximum ramp (increase in heat output)
# Unit: W/s
#
# -Qmax
# Description: Maximum possible heat output
# Unit: W
#
# -efficiency
# Description: Efficiency of the heat source
# Unit: -
#
# -PEF
# Description: Factor to convert heat source to primary energy
# Unit: -

# %% [markdown]
# Notice how the parameters are grouped per component/edge.
#
# It is also possible to print the parameters of a single component:

# %%
optmodel.print_comp_param('Producer', 'plant')
# Out:
# --- Producer.plant ---
#
# -ramp_cost
# Description: Ramping cost
# Unit: euro/(W/s)
#
# -CO2
# Description: amount of CO2 released when using primary energy source
# Unit: kg/kWh
#
# -fuel_cost
# Description: cost of fuel/electricity to generate heat
# Unit: euro/kWh
#
# -ramp
# Description: Maximum ramp (increase in heat output)
# Unit: W/s
#
# -Qmax
# Description: Maximum possible heat output
# Unit: W
#
# -efficiency
# Description: Efficiency of the heat source
# Unit: -
#
# -PEF
# Description: Factor to convert heat source to primary energy
# Unit: -

# %% [markdown]
# Or a single parameter:

# %%
optmodel.print_comp_param('BuildingAndStorage', 'storage', 'kIns')
# Out:
# --- BuildingAndStorage.storage ---
#
# -kIns
# Description: Thermal conductivity of insulation material
# Unit: W/(m.K)

# %% [markdown]
# Each of these parameters can now be given a value.
#
# For example: the general parameters (valid for the whole network)

# %%
optmodel.print_general_param()
# Out:
# --- general ---
#
# -Tg
# Description: Undisturbed ground temperature
# Unit: K
#
# -Te
# Description: Ambient temperature
# Unit: K

# %%
general_params = {'Te': t_amb,
                  'Tg': t_g}

optmodel.change_params(general_params)

# %% [markdown]
# Notice how all parameters are first grouped together in a dictionary and then given all at once to modesto.
#
# If we print the parameters again, we can see the values have now been added:

# %%
optmodel.print_general_param('Te')
# Out:
# --- general ---
#
# -Te
# Description: Ambient temperature
# Unit: K
# Value: 2014-01-01 00:00:00    283.699218
# 2014-01-01 01:00:00    283.525000
# 2014-01-01 02:00:00    283.317192
# 2014-01-01 03:00:00    283.187500
# 2014-01-01 04:00:00    283.087500
# 2014-01-01 05:00:00    282.983585
# 2014-01-01 06:00:00    282.946095
# 2014-01-01 07:00:00    282.950000
# 2014-01-01 08:00:00    283.106250
# 2014-01-01 09:00:00    283.500000
# 2014-01-01 10:00:00    283.900000
# 2014-01-01 11:00:00    284.300000
# 2014-01-01 12:00:00    284.601032
# 2014-01-01 13:00:00    284.659110
# 2014-01-01 14:00:00    284.607037
# 2014-01-01 15:00:00    284.362500
# 2014-01-01 16:00:00    284.062500
# 2014-01-01 17:00:00    283.762500
# 2014-01-01 18:00:00    283.462500
# 2014-01-01 19:00:00    283.162500
# 2014-01-01 20:00:00    282.862500
# 2014-01-01 21:00:00    282.562500
# 2014-01-01 22:00:00    282.262500
# 2014-01-01 23:00:00    281.911718
# 2014-01-02 00:00:00    281.438798
# 2014-01-02 01:00:00    280.979170
# 2014-01-02 02:00:00    280.725000
# 2014-01-02 03:00:00    280.525000
# 2014-01-02 04:00:00    280.262502
# 2014-01-02 05:00:00    280.084895
#                           ...
# 2014-12-30 18:00:00    282.500000
# 2014-12-30 19:00:00    282.100000
# 2014-12-30 20:00:00    281.700000
# 2014-12-30 21:00:00    281.300000
# 2014-12-30 22:00:00    280.970307
# 2014-12-30 23:00:00    280.537500
# 2014-12-31 00:00:00    280.037500
# 2014-12-31 01:00:00    279.537500
# 2014-12-31 02:00:00    279.209375
# 2014-12-31 03:00:00    278.962500
# 2014-12-31 04:00:00    278.658595
# 2014-12-31 05:00:00    278.421095
# 2014-12-31 06:00:00    278.225000
# 2014-12-31 07:00:00    278.129167
# 2014-12-31 08:00:00    278.202080
# 2014-12-31 09:00:00    278.375000
# 2014-12-31 10:00:00    278.575000
# 2014-12-31 11:00:00    278.720310
# 2014-12-31 12:00:00    278.812500
# 2014-12-31 13:00:00    278.861715
# 2014-12-31 14:00:00    278.794015
# 2014-12-31 15:00:00    278.638023
# 2014-12-31 16:00:00    278.300003
# 2014-12-31 17:00:00    277.962500
# 2014-12-31 18:00:00    277.662500
# 2014-12-31 19:00:00    277.303910
# 2014-12-31 20:00:00    276.961195
# 2014-12-31 21:00:00    276.607433
# 2014-12-31 22:00:00    276.076675
# 2014-12-31 23:00:00    275.791400
# Freq: 3600S, Name: Te, Length: 8760, dtype: float64

# %% [markdown]
# All of this is now repeated for the two buildings:

# %%
building1_params = {'delta_T': 20,
                    'mult': 100,
                    'night_min_temperature': night_min,
                    'night_max_temperature': night_max,
                    'day_min_temperature': day_min,
                    'day_max_temperature': day_max,
                    'bathroom_min_temperature': bathroom_min,
                    'bathroom_max_temperature': bathroom_max,
                    'floor_min_temperature': floor_min,
                    'floor_max_temperature': floor_max,
                    'model_type': 'SFH_T_5_ins_TAB',
                    'Q_sol_E': QsolE,
                    'Q_sol_W': QsolW,
                    'Q_sol_S': QsolS,
                    'Q_sol_N': QsolN,
                    'Q_int_D': Q_int_D,
                    'Q_int_N': Q_int_N,
                    'Te':  t_amb,
                    'Tg': t_g,
                    'TiD0': 20 + 273.15,
                    'TflD0': 20 + 273.15,
                    'TwiD0': 20 + 273.15,
                    'TwD0': 20 + 273.15,
                    'TfiD0': 20 + 273.15,
                    'TfiN0': 20 + 273.15,
                    'TiN0': 20 + 273.15,
                    'TwiN0': 20 + 273.15,
                    'TwN0': 20 + 273.15,
                    'max_heat': 3000
                    }

building2_params = building1_params.copy()
building2_params['mult'] = 300
building2_params['model_type'] = 'SFH_T_5_ins_TAB'

optmodel.change_params(building1_params, node='BuildingAndStorage',
                       comp='building')
optmodel.change_params(building2_params, node='Building',
                       comp='building')

# %% [markdown]
# The heat generation unit:

# %%
prod_design = {'efficiency': 0.95,
               'PEF': 1,
               'CO2': 0.178,  # based on HHV of CH4 (kg/KWh CH4)
               'fuel_cost': c_f,
               'Qmax': 1.5e7,
               'ramp_cost': 0.01,
               'ramp': 1e6 / 3600}

optmodel.change_params(prod_design, 'Producer', 'plant')

# %% [markdown]
# The storage unit:

# %%
stor_design = {
    'Thi': 80 + 273.15,
    'Tlo': 60 + 273.15,
    'mflo_max': 110,
    'mflo_min': -110,
    'volume': 2e4,
    'ar': 1,
    'dIns': 0.3,
    'kIns': 0.024,
    'heat_stor': 0,
    'mflo_use': pd.Series(0, index=t_amb.index)
}

optmodel.change_params(dict=stor_design, node='BuildingAndStorage',
                       comp='storage')

# %% [markdown]
# And the pipes:

# %%
pipe1_params = {'diameter': 500,
                'temperature_supply': 80 + 273.15,
                'temperature_return': 60 + 273.15
               }
pipe2_params = pipe1_params.copy()
pipe2_params['diameter'] = 500
pipe3_params = pipe1_params.copy()
pipe3_params['diameter'] = 500

optmodel.change_params(pipe1_params, comp='pipe1')
optmodel.change_params(pipe2_params, comp='pipe2')
optmodel.change_params(pipe3_params, comp='pipe3')

# %% [markdown]
# ## Solving the optimization problem

# %% [markdown]
# modesto now has all required data and can compile the problem.

# %%
optmodel.compile(start_time=start_time)

# %% [markdown]
# The objective of the optimization can be selected (like cost, energy or CO2):

# %%
optmodel.set_objective('cost')

# %% [markdown]
# Finally, the problem can be solved:

# %% [markdown]
# Currently, modesto is compatible with two solvers, namely `cplex` and `gurobi`.

# %%
optmodel.solve(tee=True, mipgap=0.1, solver='cplex', warmstart=True)
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 12.8.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2017.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'c:\users\u0094934\appdata\local\temp\tmp7skv1j.cplex.log' open.
# CPLEX> New value for mixed integer optimality gap tolerance: 0.1
# CPLEX> New value for level of mixed integer node display: 3
# CPLEX> New value for feasibility pump heuristic: 2
# CPLEX> Problem 'c:\users\u0094934\appdata\local\temp\tmpxkzyqb.pyomo.lp' read.
# Read time = 0.03 sec. (1.53 ticks)
# CPLEX> Problem name         : c:\users\u0094934\appdata\local\temp\tmpxkzyqb.pyomo.lp
# Objective sense      : Minimize
# Variables            :   12142  [Nneg: 1081,  Box: 360,  Free: 10341,
#                                  Binary: 360]
# Objective nonzeros   :     121
# Linear constraints   :   14189  [Less: 3246,  Greater: 840,  Equal: 10103]
#   Nonzeros           :   37104
#   RHS nonzeros       :    6026
#
# Variables            : Min LB: -9196000.        Max UB: 1.500000e+07
# Objective nonzeros   : Min   : 0.002689474      Max   : 1.000000
# Linear constraints   :
#   Nonzeros           : Min   : 1.196172e-05     Max   : 1000000.
#   RHS nonzeros       : Min   : 0.03106533       Max   : 1000000.
# CPLEX> CPXPARAM_MIP_Tolerances_MIPGap                   0.10000000000000001
# CPXPARAM_MIP_Display                             3
# CPXPARAM_MIP_Strategy_FPHeur                     2
# Tried aggregator 4 times.
# MIP Presolve eliminated 3714 rows and 1422 columns.
# MIP Presolve modified 2996 coefficients.
# Aggregator did 8391 substitutions.
# Reduced MIP has 2084 rows, 2329 columns, and 13360 nonzeros.
# Reduced MIP has 351 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.06 sec. (30.14 ticks)
# Found incumbent of value 5808181.565322 after 0.17 sec. (126.68 ticks)
# Probing fixed 1 vars, tightened 0 bounds.
# Probing time = 0.05 sec. (2.04 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 1 rows and 2 columns.
# Reduced MIP has 2083 rows, 2327 columns, and 13356 nonzeros.
# Reduced MIP has 350 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (6.17 ticks)
# Probing time = 0.03 sec. (1.61 ticks)
# Clique table members: 6.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.33 sec. (250.63 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                      5808181.5653    29004.5665            99.50%
# Found incumbent of value 5808181.565322 after 0.61 sec. (392.54 ticks)
#       0     0  2071148.5906   191  5808181.5653  2071148.5906     1567   64.34%
# *     0+    0                      2157716.1184  2071148.5906             4.01%
# Found incumbent of value 2157716.118354 after 1.31 sec. (824.07 ticks)
#
# Root node processing (before b&c):
#   Real time             =    1.51 sec. (824.91 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    1.51 sec. (824.91 ticks)
#
# Solution pool: 2 solutions saved.
#
# MIP - Integer optimal, tolerance (0.1/1e-06):  Objective =  2.1577161184e+06
# Current MIP best bound =  2.0711485906e+06 (gap = 86567.5, 4.01%)
# Solution time =    1.51 sec.  Iterations = 1567  Nodes = 0 (1)
# Deterministic time = 824.95 ticks  (544.52 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'c:\users\u0094934\appdata\local\temp\tmpffgcqu.cplex.sol'.
# CPLEX>
# 0

# %%
optmodel.solve(tee=True, mipgap=0.2, solver='cplex')
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 12.8.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2017.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'c:\users\u0094934\appdata\local\temp\tmppmh4r0.cplex.log' open.
# CPLEX> New value for mixed integer optimality gap tolerance: 0.2
# CPLEX> New value for level of mixed integer node display: 3
# CPLEX> New value for feasibility pump heuristic: 2
# CPLEX> Problem 'c:\users\u0094934\appdata\local\temp\tmpnrxfid.pyomo.lp' read.
# Read time = 0.05 sec. (1.53 ticks)
# CPLEX> Problem name         : c:\users\u0094934\appdata\local\temp\tmpnrxfid.pyomo.lp
# Objective sense      : Minimize
# Variables            :   12142  [Nneg: 1081,  Box: 360,  Free: 10341,
#                                  Binary: 360]
# Objective nonzeros   :     121
# Linear constraints   :   14189  [Less: 3246,  Greater: 840,  Equal: 10103]
#   Nonzeros           :   37104
#   RHS nonzeros       :    6026
#
# Variables            : Min LB: -9196000.        Max UB: 1.500000e+07
# Objective nonzeros   : Min   : 0.002689474      Max   : 1.000000
# Linear constraints   :
#   Nonzeros           : Min   : 1.196172e-05     Max   : 1000000.
#   RHS nonzeros       : Min   : 0.03106533       Max   : 1000000.
# CPLEX> CPXPARAM_MIP_Tolerances_MIPGap                   0.20000000000000001
# CPXPARAM_MIP_Display                             3
# CPXPARAM_MIP_Strategy_FPHeur                     2
# Tried aggregator 4 times.
# MIP Presolve eliminated 3714 rows and 1422 columns.
# MIP Presolve modified 2996 coefficients.
# Aggregator did 8391 substitutions.
# Reduced MIP has 2084 rows, 2329 columns, and 13360 nonzeros.
# Reduced MIP has 351 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.06 sec. (30.14 ticks)
# Found incumbent of value 5808181.565322 after 0.16 sec. (126.68 ticks)
# Probing fixed 1 vars, tightened 0 bounds.
# Probing time = 0.01 sec. (2.04 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 1 rows and 2 columns.
# Reduced MIP has 2083 rows, 2327 columns, and 13356 nonzeros.
# Reduced MIP has 350 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (6.17 ticks)
# Probing time = 0.02 sec. (1.61 ticks)
# Clique table members: 6.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.28 sec. (250.63 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                      5808181.5653    29004.5665            99.50%
# Found incumbent of value 5808181.565322 after 0.50 sec. (392.54 ticks)
#       0     0  2071148.5906   191  5808181.5653  2071148.5906     1567   64.34%
# *     0+    0                      2157716.1184  2071148.5906             4.01%
# Found incumbent of value 2157716.118354 after 1.28 sec. (824.07 ticks)
#
# Root node processing (before b&c):
#   Real time             =    1.44 sec. (824.91 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    1.44 sec. (824.91 ticks)
#
# Solution pool: 2 solutions saved.
#
# MIP - Integer optimal, tolerance (0.2/1e-06):  Objective =  2.1577161184e+06
# Current MIP best bound =  2.0711485906e+06 (gap = 86567.5, 4.01%)
# Solution time =    1.44 sec.  Iterations = 1567  Nodes = 0 (1)
# Deterministic time = 824.95 ticks  (574.07 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'c:\users\u0094934\appdata\local\temp\tmp83sp37.cplex.sol'.
# CPLEX>
# 0

# %% [markdown]
# ## Collecting results

# %% [markdown]
# ### The objective(s)
#
# The get_objective_function gets the value of the active objective (if no input) or of a specific objective if an extra input is given (not necessarily active, hence not an optimal value).

# %%
print 'Active:', optmodel.get_objective()
print 'Energy:', optmodel.get_objective('energy')
print 'Cost:  ', optmodel.get_objective('cost')
# Out:
# Active: 2157716.11835
# Energy: 168732.013288
# Cost:   2157716.11835

# %% [markdown]
# modesto has the get_result method, whch allows to get the optimal values of the optimization variables:

# %% [markdown]
# ### Buildings
#
# Collecting the data for the Building.building component:

# %%
TiD = optmodel.get_result('StateTemperatures', node='Building',
                           comp='building', index='TiD', state=True)
TflD = optmodel.get_result('StateTemperatures', node='Building',
                           comp='building', index='TflD', state=True)
TwiD = optmodel.get_result('StateTemperatures', node='Building',
                           comp='building', index='TwiD', state=True)
TwD = optmodel.get_result('StateTemperatures', node='Building',
                           comp='building', index='TwD', state=True)
TfiD = optmodel.get_result('StateTemperatures', node='Building',
                            comp='building', index='TfiD', state=True)
TfiN = optmodel.get_result('StateTemperatures', node='Building',
                            comp='building', index='TfiN', state=True)
TiN = optmodel.get_result('StateTemperatures', node='Building',
                           comp='building', index='TiN', state=True)
TwiN = optmodel.get_result('StateTemperatures', node='Building',
                            comp='building', index='TwiN', state=True)
TwN = optmodel.get_result('StateTemperatures', node='Building',
                           comp='building', index='TwN', state=True)
Q_hea_D = optmodel.get_result('ControlHeatFlows', node='Building',
                                comp='building', index='Q_hea_D')
Q_hea_N = optmodel.get_result('ControlHeatFlows', node='Building',
                                comp='building', index='Q_hea_N')

# %% [markdown]
# Creating plots:

# %%
userprofile = ut.read_period_data(path=DATAPATH, name='UserBehaviour/ISO13790.csv',
                                time_step=time_step, horizon=horizon, start_time=start_time)

day_max = userprofile['day_max']
day_min = userprofile['day_min']
night_max = userprofile['night_max']
night_min = userprofile['night_min']

fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
# ax1 = fig1.add_subplot(221)
ax1.plot(day_max, label='maximum', linestyle='--', color='k')
ax1.plot(day_min, label='minimum', linestyle='--', color='k')
ax1.plot(TiD, label='Building.building')
ax1.legend()
ax1.set_title('Day zone temperatures')

fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.plot(night_max, label='maximum', linestyle='--', color='k')
ax2.plot(night_min, label='minimum', linestyle='--', color='k')
ax2.plot(TiN, label='Building.building')
ax2.legend()
ax2.set_title('Night zone temperatures')

fig3 = plt.figure()
ax3 = fig3.add_subplot(111)
ax3.plot(Q_hea_D)
ax3.set_title('Day zone heat [W]')

fig4 = plt.figure()
ax4 = fig4.add_subplot(111)
ax4.plot(Q_hea_N)
ax4.set_title('Night zone heat [W]')

fig5 = plt.figure()
ax5 = fig5.add_subplot(111)
ax5.plot(TiD, label='TiD')
ax5.plot(TflD, label='TflD')
ax5.plot(TwiD, label='TwiD')
ax5.plot(TwD, label='TwD')
ax5.plot(TfiD, label='TfiD')
ax5.plot(day_max, label='maximum', linestyle='--', color='k')
ax5.plot(day_min, label='minimum', linestyle='--', color='k')
ax5.legend()
ax5.set_title('Day state temperatures [K]')

fig6 = plt.figure()
ax6 = fig6.add_subplot(111)
ax6.plot(TfiN, label='TfiN')
ax6.plot(TiN, label='TiN')
ax6.plot(TwiN, label='TwiN')
ax6.plot(TwN, label='TwN')
ax6.plot(night_max, label='maximum', linestyle='--', color='k')
ax6.plot(night_min, label='minimum', linestyle='--', color='k')
ax6.legend()
ax6.set_title('Night state temperatures [K]')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,u'Night state temperatures [K]')

# %% [markdown]
# ## Storage unit

# %%
storage_stored_heat = optmodel.get_result('heat_stor', node='BuildingAndStorage',
                                  comp='storage')
storage_heat_flow = optmodel.get_result('heat_flow', node='BuildingAndStorage',
                                 comp='storage')

# %%
fig1, (ax, ax2) = plt.subplots(2,1, sharex=True)
ax.plot(storage_stored_heat)
ax.set_title('Stored heat [kWh]')
ax2.plot(storage_heat_flow)
ax2.set_title('Heat flow to the tank [kWh]')
ax2.axhline(linestyle='--', color='g')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Heat generation unit

# %%
prod_hf = optmodel.get_result('heat_flow', node='Producer', comp='plant')
c_f = ut.read_period_data(path=DATAPATH,
                          name='ElectricityPrices/DAM_electricity_prices-2014_BE.csv',
                          time_step=time_step, horizon=horizon,
                          start_time=start_time)['price_BE']

# %%
fig, (ax, ax1) = plt.subplots(2, 1 , sharex=True)
ax.plot(prod_hf)

ax.axhline(y=0, linewidth=2, color='k', linestyle='--')
ax.set_title('Producer heat flows [W]')

ax1.plot(c_f)
ax1.set_title('Fuel price (electricity) euro/MWh')
ax1.legend()
#fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The plot clearly shows that the cost objective is followed, with the heat generation unit preferring moments of low electricity price to inject heat into the network.
#
# Looking at the plots of the storage unit, you can see that most of this heat is stored there and used at a later time to keep the buildings sufficiently warm.

# %% [markdown]
# ## Network efficiency

# %%
# Heat flows
prod_hf = optmodel.get_result('heat_flow', node='Producer', comp='plant')
storage_hf = optmodel.get_result('heat_flow', node='BuildingAndStorage',
                                 comp='storage')
waterschei_hf = optmodel.get_result('heat_flow', node='BuildingAndStorage',
                                    comp='building')
zwartberg_hf = optmodel.get_result('heat_flow', node='Building',
                                   comp='building')


# Sum of heat flows
prod_e = sum(prod_hf)
storage_e = sum(storage_hf)
waterschei_e = sum(waterschei_hf)
zwartberg_e = sum(zwartberg_hf)

# Efficiency
print '\nNetwork efficiency', (storage_e + waterschei_e + zwartberg_e) / prod_e * 100, '%'
# Out:
# Network efficiency 94.0222630881 %
